# %%
#r "nuget: dotNetRdf, 3.0.1"
#r "nuget: dotNetRdf.Dynamic, 3.0.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>dotNetRdf, 3.0.1</span></li><li><span>dotnetrdf.dynamic, 3.0.1</span></li></ul></div></div>

# %%
using System;
using System.Collections.Generic;
using VDS.RDF;
using VDS.RDF.Writing;
using VDS.RDF.Dynamic;

# %%
var g = new Graph();
g.NamespaceMap.AddNamespace("se", new Uri("http://github.com/usalu/semio/schema/linkeddata/semio.ttl#"));
g.NamespaceMap.AddNamespace("ct", new Uri("http://github.com/usalu/semio/examples/nakagincapsuletower/repository.ttl#"));
var d = g.AsDynamic(UriFactory.Create("se:"));
d["s"] = new { p = "o" };
g.
# Out:
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>VDS.RDF.Graph</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>UriFactory</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>VDS.RDF.CachingUriFactory</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>InternUris</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>Triples</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ se:s , se:p , o^^http://www.w3.org/2001/XMLSchema#string ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>ObjectNodes</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ o^^http://www.w3.org/2001/XMLSchema#string ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Count</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>IsReadOnly</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td><i>(values)</i></td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>o^^http://www.w3.org/2001/XMLSchema#string</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>EffectiveType</td><td><div class="dni-plaintext"><pre>http://www.w3.org/2001/XMLSchema#string</pre></div></td></tr><tr><td>NumericType</td><td><span>NaN</span></td></tr><tr><td>Value</td><td><div class="dni-plaintext"><pre>o</pre></div></td></tr><tr><td>Language</td><td><div class="dni-plaintext"><pre></pre></div></td></tr><tr><td>DataType</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>http://www.w3.org/2001/XMLSchema#string</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>AbsolutePath</td><td><div class="dni-plaintext"><pre>/2001/XMLSchema</pre></div></td></tr><tr><td>AbsoluteUri</td><td><div class="dni-plaintext"><pre>http://www.w3.org/2001/XMLSchema#string</pre></div></td></tr><tr><td>LocalPath</td><td><div class="dni-plaintext"><pre>/2001/XMLSchema</pre></div></td></tr><tr><td>Authority</td><td><div class="dni-plaintext"><pre>www.w3.org</pre></div></td></tr><tr><td>HostNameType</td><td><span>Dns</span></td></tr><tr><td>IsDefaultPort</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>IsFile</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>IsLoopback</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>PathAndQuery</td><td><div class="dni-plaintext"><pre>/2001/XMLSchema</pre></div></td></tr><tr><td>Segments</td><td><div class="dni-plaintext"><pre>[ /, 2001/, XMLSchema ]</pre></div></td></tr><tr><td>IsUnc</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>Host</td><td><div class="dni-plaintext"><pre>www.w3.org</pre></div></td></tr><tr><td>Port</td><td><div class="dni-plaintext"><pre>80</pre></div></td></tr><tr><td>Query</td><td><div class="dni-plaintext"><pre></pre></div></td></tr><tr><td>Fragment</td><td><div class="dni-plaintext"><pre>#string</pre></div></td></tr><tr><td>Scheme</td><td><div class="dni-plaintext"><pre>http</pre></div></td></tr><tr><td>OriginalString</td><td><div class="dni-plaintext"><pre>http://www.w3.org/2001/XMLSchema#string</pre></div></td></tr><tr><td>DnsSafeHost</td><td><div class="dni-plaintext"><pre>www.w3.org</pre></div></td></tr><tr><td>IdnHost</td><td><div class="dni-plaintext"><pre>www.w3.org</pre></div></td></tr><tr><td>IsAbsoluteUri</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>UserEscaped</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>UserInfo</td><td><div class="dni-plaintext"><pre></pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>NodeType</td><td><span>Literal</span></td></tr></tbody></table></ ...
